# %%
df_silver = spark.table("resume_silver")
df_silver.select("resume_file", "extracted_skills").show(truncate=False)
# Out:
# +-----------------------+-------------------------------------------------------------------------------+
# |resume_file            |extracted_skills                                                               |
# +-----------------------+-------------------------------------------------------------------------------+
# |Resume_Akash_Verma.pdf |[python, sql, pyspark, databricks, spark, etl]                                 |
# |Resume_Ananya_Gupta.pdf|[python, sql, machine learning, nlp, spacy]                                    |
# |Resume_Karthik_R.pdf   |[python, sql]                                                                  |
# |Resume_Rohan_Sharma.pdf|[python, sql, machine learning, nlp, pyspark, databricks, spark, data analysis]|
# |Resume_Sneha_Iyer.pdf  |[python, sql, machine learning, pandas, data analysis]                         |
# +-----------------------+-------------------------------------------------------------------------------+

# %%
jd_path = "/Volumes/resume/data/volume/jd.txt"

with open(jd_path, "r") as f:
    jd_text = f.read().lower()

jd_text
# Out:
# '\ufeffwe are looking for an ai/ml intern with strong fundamentals in python and machine learning.\nthe candidate should have experience with sql, data analysis, and nlp techniques.\nhands-on exposure to pyspark and databricks is a plus.\nfamiliarity with etl pipelines, data preprocessing, and basic deep learning concepts is desirable.'

# %%
skills_list = [
    "python",
    "sql",
    "machine learning",
    "deep learning",
    "nlp",
    "pyspark",
    "databricks",
    "spark",
    "pandas",
    "numpy",
    "spacy",
    "etl",
    "data analysis"
]

jd_skills = [skill for skill in skills_list if skill in jd_text]
jd_skills
# Out:
# ['python',
#  'sql',
#  'machine learning',
#  'deep learning',
#  'nlp',
#  'pyspark',
#  'databricks',
#  'spark',
#  'etl',
#  'data analysis']

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import StructType, StructField, IntegerType, StringType

def score_resume(resume_skills):
    matched = list(set(resume_skills) & set(jd_skills))
    missing = list(set(jd_skills) - set(resume_skills))

    score = int((len(matched) / len(jd_skills)) * 100) if jd_skills else 0

    return score, ", ".join(matched), ", ".join(missing)

score_schema = StructType([
    StructField("score", IntegerType()),
    StructField("matched_skills", StringType()),
    StructField("missing_skills", StringType())
])

score_udf = udf(score_resume, score_schema)

# %%
df_gold = df_silver.withColumn(
    "score_struct",
    score_udf("extracted_skills")
)

df_gold = df_gold \
    .withColumn("score", df_gold.score_struct.score) \
    .withColumn("matched_skills", df_gold.score_struct.matched_skills) \
    .withColumn("missing_skills", df_gold.score_struct.missing_skills) \
    .drop("score_struct")

df_gold.select(
    "resume_file",
    "score",
    "matched_skills",
    "missing_skills"
).show(truncate=False)
# Out:
# +-----------------------+-----+-----------------------------------------------------------------------------+------------------------------------------------------------------------------------+
# |resume_file            |score|matched_skills                                                               |missing_skills                                                                      |
# +-----------------------+-----+-----------------------------------------------------------------------------+------------------------------------------------------------------------------------+
# |Resume_Akash_Verma.pdf |60   |sql, pyspark, databricks, etl, python, spark                                 |machine learning, data analysis, deep learning, nlp                                 |
# |Resume_Ananya_Gupta.pdf|40   |machine learning, sql, python, nlp                                           |data analysis, deep learning, pyspark, databricks, etl, spark                       |
# |Resume_Karthik_R.pdf   |20   |sql, python                                                                  |data analysis, deep learning, pyspark, nlp, machine learning, databricks, etl, spark|
# |Resume_Rohan_Sharma.pdf|80   |sql, data analysis, pyspark, nlp, machine learning, databricks, python, spark|etl, deep learning                                                                  |
# |Resume_Sneha_Iyer.pdf  |40   |machine learning, python, sql, data analysis                                 |deep learning, pyspark, nlp, databricks, etl, spark                                 |
# +-----------------------+-----+-----------------------------------------------------------------------------+------------------------------------------------------------------------------------+

# %%
df_ranked = df_gold.orderBy(df_gold.score.desc())
df_ranked.show(truncate=False)
# Out:
# +-----------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------+-----+-----------------------------------------------------------------------------+------------------------------------------------------------------------------------+
# |resume_file            |resume_text                                                                                                                                                                                                                                                                                                                                                                                           |resume_text_clean                                                                                                                                                                                                                                                                                                                                                                                     |extracted_skills                                                               |score|matched_skills                                                               |missing_skills                                                                      |
# +-----------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------+-----+-----------------------------------------------------------------------------+------------------------------------------------------------------------------------+
# |Resume_Rohan_Sharma.pdf|Rohan Sharma\nEmail: rohan.sharma@gmail.com\nPhone: +91 98765 43210\nLocation: Bengaluru, India\nEducation:\nB.Tech Computer Science, VIT (2021–2025), CGPA 8.6\nSkills:\nPython, Machine Learning, SQL, PySpark, Databricks, NLP\nProjects:\nResume Screening System using NLP\nSales Data Analysis using PySpark\nInternship:\nData Science Intern – ABC Tech\n                                     |rohan sharma\nemail: rohan.sharma@gmail.com\nphone: +91 98765 43210\nlocation: bengaluru, india\neducation:\nb.tech computer science, vit (2021–2025), cgpa 8.6\nskills:\npython, machine learning, sql, pyspark, databricks, nlp\nprojects:\nresume screening system using nlp\nsales data analysis using pyspark\ninternship:\ndata science intern – abc tech\n                                     |[python, sql, machine learning, nlp, pyspark, databricks, spark, data analysis]|80   |sql, data analysis, pyspark, nlp, machine learning, databricks, python, spark|etl, deep learning                                                                  |
# |Resume_Akash_Verma.pdf |Akash Verma\nEmail: akash.verma22@outlook.com\nPhone: +91 91234 56789\nLocation: Hyderabad, India\nEducation:\nB.Tech IT, SRM University (2021–2025)\nSkills:\nPython, SQL, PySpark, Databricks, ETL\nProjects:\nETL Pipeline using Medallion Architecture\n                                                                                                                                          |akash verma\nemail: akash.verma22@outlook.com\nphone: +91 91234 56789\nlocation: hyderabad, india\neducation:\nb.tech it, srm university (2021–2025)\nskills:\npython, sql, pyspark, databricks, etl\nprojects:\netl pipeline using medallion architecture\n                                                                                                                                          |[python, sql, pyspark, databricks, spark, etl]                                 |60   |sql, pyspark, databricks, etl, python, spark                                 |machine learning, data analysis, deep learning, nlp                                 |
# |Resume_Ananya_Gupta.pdf|Ananya Gupta\nEmail: ananya.gupta@protonmail.com\nPhone: +91 90987 65432\nLocation: Pune, India\nEducation:\nB.Tech Artificial Intelligence & Data Science, MIT-WPU (2021–2025), CGPA 8.4\nSkills:\nPython, NLP, spaCy, Machine Learning, SQL, Data Visualization\nProjects:\nNamed Entity Recognition using spaCy\nChatbot for Recruitment Assistance\nInternship:\nAI Intern – SmartHire Solutions\n|ananya gupta\nemail: ananya.gupta@protonmail.com\nphone: +91 90987 65432\nlocation: pune, india\neducation:\nb.tech artificial intelligence & data science, mit-wpu (2021–2025), cgpa 8.4\nskills:\npython, nlp, spacy, machine learning, sql, data visualization\nprojects:\nnamed entity recognition using spacy\nchatbot for recruitment assistance\ninternship:\nai intern – smarthire solutions\n|[python, sql, machine learning, nlp, spacy]                                    |40   |machine learning, sql, python, nlp                                           |data analysis, deep learning, pyspark, databricks, etl, spark                       |
# |Resume_Sneha_Iyer.pdf  |Sneha Iyer\nEmail: sneha.iyer@gmail.com\nPhone: +91 99887 66554\nLocation: Chennai, India\nEducation:\nB.Sc Computer Science, Loyola College (2021–2024), CGPA 7.8\nSkills:\nPython, SQL, Machine Learning basics, Pandas, Excel\nProjects:\nStudent Performance Prediction using ML\nData Analysis using Python\nCertification:\nPython for Data Science – Coursera\n                                |sneha iyer\nemail: sneha.iyer@gmail.com\nphone: +91 99887 66554\nlocation: chennai, india\neducation:\nb.sc computer science, loyola college (2021–2024), cgpa 7.8\nskills:\npython, sql, machine learning basics, pandas, excel\nprojects:\nstudent performance prediction using ml\ndata analysis using python\ncertification:\npython for data science – coursera\n                                |[python, sql, machine learning, pandas, data analysis]                         |40   |machine learning, python, sql, data analysis                                 |deep learning, pyspark, nlp, databricks, etl, spark                                 |
# |Resume_Karthik_R.pdf   |Karthik R\nEmail: karthik.r@gmail.com\nPhone: +91 90123 45678\nLocation: Coimbatore, India\nEducation:\nB.E Mechanical Engineering, Anna University (2020–2024), CGPA 7.2\nSkills:\nPython, Excel, Basic SQL\nProjects:\nInventory Management System using Python\nExperience:\nFresher\n                                                                                                             |karthik r\nemail: karthik.r@gmail.com\nphone: +91 90123 45678\nlocation: coimbatore, india\neducation:\nb.e mechanical engineering, anna university (2020–2024), cgpa 7.2\nskills:\npython, excel, basic sql\nprojects:\ninventory management system using python\nexperience:\nfresher\n                                                                                                             |[python, sql]                                                                  |20   |sql, python                                                                  |data analysis, deep learning, pyspark, nlp, machine learning, databricks, etl, spark|
# +-----------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------+-----+-----------------------------------------------------------------------------+------------------------------------------------------------------------------------+

# %%
df_ranked.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("resume_gold")

# %%
df_ranked \
    .select("resume_file", "score", "matched_skills", "missing_skills") \
    .coalesce(1) \
    .write \
    .mode("overwrite") \
    .option("header", True) \
    .csv("/Volumes/resume/data/volume/output/candidate_ranking")
